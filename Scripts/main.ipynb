# %% [markdown]
# # Imports

# %%
# %reset -f

# %%
import shutil
import json
from pathlib import Path

from tqdm import tqdm
import pandas as pd

import requests
from bardapi import Bard, SESSION_HEADERS

# %%
PATH_PREFIX = '../'

PATHS = [
    PATH_PREFIX + 'multiling-multichoice-rc-master/dataset/Bulgarian',
    PATH_PREFIX + 'multiling-multichoice-rc-master/dataset/Croatian',
    PATH_PREFIX + 'multiling-multichoice-rc-master/dataset/Chinese',
    PATH_PREFIX + 'multiling-multichoice-rc-master/dataset/Hungarian',
    PATH_PREFIX + 'multiling-multichoice-rc-master/dataset/Polish',
    PATH_PREFIX + 'multiling-multichoice-rc-master/dataset/English',
]

QUESTIONS_COLS = ['id', 'answer_key', 'question_snapshot', 'question_number', 'grade', 'subject', 'language', 'date']

# %% [markdown]
# # Load data

# %%
def preprocess(filepath: str) -> str:
    if 'multimodal_dataset' in filepath:
        filepath = filepath[1:]
        filepath = filepath.replace('multimodal_dataset\\', 'dataset\\')
        filepath = filepath.replace('\\', '/')
    
    if filepath.startswith('data'):
        filepath = 'multiling-multichoice-rc-master/dataset/Chinese/' + filepath
    
    if 'Croatian/exams_to_annotate' in filepath:
        filepath = filepath.replace('exams_to_annotate', 'annotated')
    
    filepath = filepath.replace('JEE-Advanced/', '')

    filepath = PATH_PREFIX + filepath
    return filepath


paths = [Path(path) for path in PATHS]
assert all([path.exists() for path in paths]
            ), f'ERROR: Not all paths are present.'

annotations = []
questions = []

for path in paths:
    jsons = list(path.rglob('*.json'))
    # Because we use the annotation files
    # here there is an implicit filter
    # that removes the questions of type "instruction"
    exam_annotations = list(filter(lambda json_path: 'annotation' in json_path.stem, jsons))
    annotations.extend(exam_annotations)
    for exam in exam_annotations:
        questions.extend(json.loads(exam.read_bytes()))

for annotation_file in annotations:
    current_annotations = json.loads(annotation_file.read_bytes())
    for current_annotation in current_annotations:
        current_annotation['question']['question_snapshot'] = preprocess(current_annotation['question']['question_snapshot'])
        filepath = current_annotation['question']['question_snapshot']
        assert Path(filepath).exists(), f'ERROR: Path {filepath} does not exist!'

print('All images exist!')

df_questions = pd.json_normalize(questions)
df_questions.columns = QUESTIONS_COLS
df_questions['question_snapshot'] = df_questions['question_snapshot'].apply(preprocess)

assert df_questions['question_snapshot'].apply(lambda filepath: Path(filepath).exists()).all(), 'ERROR: Some image paths do not exist!'

df_questions
# Out:
# All images exist!
#                                          id answer_key  \
# 0      6d2efd56-6bed-43ec-af58-653d0dac578d          А
# 1      da5dd867-163c-4400-a316-57e32ba072e0          Г
# 2      10d911fb-fca1-4a16-aad2-87254b13d52b          А
# 3      58495517-d5fa-4391-aefa-77405e9586d1          А
# 4      559bcfe6-e72a-4fb5-b0c9-5c07fd91a507          В
# ...                                     ...        ...
# 17415  e88b9858-72e6-4733-9fbe-84a30e79cf0d          B
# 17416  a441aa2a-2cb8-4576-ab40-41ac48f33778          A
# 17417  a4be2ba5-9d50-42a2-8943-47eebe3a7a7d          B
# 17418  910bdfef-52e1-4f0e-bdf4-d6aa145974e3          D
# 17419  92187ce4-c0ec-4acb-87c1-8e2a5e13089d          C
#
#                                        question_snapshot  question_number  \
# 0      ../multiling-multichoice-rc-master/dataset/Bul...                1
# 1      ../multiling-multichoice-rc-master/dataset/Bul...                2
# 2      ../multiling-multichoice-rc-master/dataset/Bul...                3
# 3      ../multiling-multichoice-rc-master/dataset/Bul...                4
# 4      ../multiling-multichoice-rc-master/dataset/Bul...                5
# ...                                                  ...              ...
# 17415  ../multiling-multichoice-rc-master/dataset/Eng...               26
# 17416  ../multiling-multichoice-rc-master/dataset/Eng...               27
# 17417  ../multiling-multichoice-rc-master/dataset/Eng...               28
# 17418  ../multiling-multichoice-rc-master/dataset/Eng...               29
# 17419  ../multiling-multichoice-rc-master/dataset/Eng...               30
#
#        grade      subject   language        date
# 0         12      Physics  Bulgarian  2019-05-23
# 1         12      Physics  Bulgarian  2019-05-23
# 2         12      Physics  Bulgarian  2019-05-23
# 3         12      Physics  Bulgarian  2019-05-23
# 4         12      Physics  Bulgarian  2019-05-23
# ...      ...          ...        ...         ...
# 17415     12  Mathematics    English        2013
# 17416     12  Mathematics    English        2013
# 17417     12  Mathematics    English        2013
# 17418     12  Mathematics    English        2013
# 17419     12  Mathematics    English        2013
#
# [17420 rows x 8 columns]

# %%
pd.concat([
    df_questions['language'].value_counts(dropna=False),
    df_questions['language'].value_counts(dropna=False, normalize=True).round(4) * 100,
], axis=1)
# Out:
#            count  proportion
# language
# Croatian    3973       22.81
# Hungarian   3801       21.82
# Chinese     2635       15.13
# Polish      2511       14.41
# Bulgarian   2132       12.24
# German       819        4.70
# English      480        2.76
# French       439        2.52
# Spanish      299        1.72
# Serbian      227        1.30
# Slovakian     46        0.26
# Italian       44        0.25
# Russian        9        0.05
# Romanian       5        0.03

# %%
# Use the path to each cropped image
# to form the path of the bounding box file.
# Because the filenames of the cropped images are sorted,
# the i-th row of the bounding box file corresponds to the i-th image.
# That should mean that if you zip the two, you'll get the type of the image.

def get_type(cropped_image_path: str) -> str:
    cropped_image_path = Path(cropped_image_path)
    parent = cropped_image_path.parent

    if 'cropped_images' not in parent.name:
        return parent.name
    
    bbox_path = parent.parent / 'bbox'
    if not bbox_path.exists():
        bbox_path = parent.parent / 'bboxes'
    assert bbox_path.exists(), f'ERROR: Path {bbox_path} does not exist!'

    parts = cropped_image_path.stem.split('_')
    assert len(parts) == 4, f'ERROR: Length of "parts" has to be 4, but is {len(parts)}!'

    _, bbox_num, _, orig_line_num = parts
    bbox_num, orig_line_num = int(bbox_num), int(orig_line_num)

    bbox_path_page = bbox_path / f'page_{bbox_num}.txt'
    if not bbox_path_page.exists():
        bbox_path_page = bbox_path / f'page_0{bbox_num}.txt'
    assert bbox_path_page.exists(), f'ERROR: Cannot find {bbox_path_page}!'

    with open(bbox_path_page) as f:
        lines = f.readlines()
    
    n_lines = len(lines)
    line_num = orig_line_num
    if n_lines <= orig_line_num - 2:
        line_num = orig_line_num // n_lines - 1
    elif n_lines <= orig_line_num:
        line_num = orig_line_num - 2
    assert n_lines > line_num, f'ERROR: Line numbers do not math {n_lines=} <= {line_num=} for {str(cropped_image_path)=}!'

    question_type_idx = lines[line_num][0]
    question_type = 'text' if question_type_idx == '0' else 'image_text'
    return question_type


df_questions['type'] = 'NA'
idxs = df_questions.query('language != "Chinese"').index
df_questions.loc[idxs, 'type'] = df_questions.loc[idxs, 'question_snapshot'].apply(get_type)
df_questions['type'].value_counts(dropna=False)
# Out:
# type
# text          11928
# image_text     2857
# NA             2635
# Name: count, dtype: int64

# %%
pd.crosstab(df_questions['language'], df_questions['type'], margins=True, dropna=False)
# Out:
# type         NA  image_text   text    All
# language
# Bulgarian     0         501   1631   2132
# Chinese    2635           0      0   2635
# Croatian      0         713   3260   3973
# English       0         123    357    480
# French        0          66    373    439
# German        0         174    645    819
# Hungarian     0         695   3106   3801
# Italian       0           4     40     44
# Polish        0         421   2090   2511
# Romanian      0           0      5      5
# Russian       0           0      9      9
# Serbian       0          67    160    227
# Slovakian     0           4     42     46
# Spanish       0          89    210    299
# All        2635        2857  11928  17420

# %%
df_questions.groupby(by=['language', 'grade', 'type']).agg(number_questions=('id', 'count'))
# Out:
#                             number_questions
# language  grade type
# Bulgarian 4     image_text                41
#                 text                     456
#           12    image_text               460
#                 text                    1175
# Chinese   4     NA                      2635
# Croatian  12    image_text               713
#                 text                    3260
# English   12    image_text               123
#                 text                     357
# French    12    image_text                66
#                 text                     373
# German    12    image_text               174
#                 text                     645
# Hungarian 12    image_text               695
#                 text                    3106
# Italian   12    image_text                 4
#                 text                      40
# Polish    12    image_text               421
#                 text                    2090
# Romanian  12    text                       5
# Russian   12    text                       9
# Serbian   12    image_text                67
#                 text                     160
# Slovakian 12    image_text                 4
#                 text                      42
# Spanish   12    image_text                89
#                 text                     210

# %%
df_questions.groupby(by=['language', 'subject']).agg(number_questions=('id', 'count'))
# Out:
#                            number_questions
# language  subject
# Bulgarian Chemistry                     665
#           Man and Nature                233
#           Man and Society               264
#           Physics                       970
# Chinese   Biology                       281
# ...                                     ...
# Serbian   Geography                       6
#           Physics                       185
# Slovakian Chemistry                      46
# Spanish   Geography                      19
#           Physics                       280
#
# [112 rows x 1 columns]

# %% [markdown]
# # Normalize the subjects

# %% [markdown]
# ## Initial frequency analysis

# %%
df_questions['subject'].value_counts(dropna=False).sort_index()
# Out:
# subject
# Accounting                                                           40
# Administration                                                       37
# Agriculture                                                         652
# Assisting the dentist and keeping the office ready for work          80
# Biology                                                             855
#                                                                    ...
# Sociology                                                           295
# Tourism                                                              76
# Use of vehicles, machines, devices and tools used in agriculture     40
# customer service in administration units                             40
# organizing and conducting the motor vehicle service process          40
# Name: count, Length: 81, dtype: int64

# %%
df_questions.groupby(by='language')['subject'].nunique()
# Out:
# language
# Bulgarian     4
# Chinese       6
# Croatian     17
# English       3
# French        3
# German        5
# Hungarian     8
# Italian       2
# Polish       55
# Romanian      1
# Russian       1
# Serbian       4
# Slovakian     1
# Spanish       2
# Name: subject, dtype: int64

# %% [markdown]
# ## Aggregate subjects

# %%
subjects_polish = df_questions.query('language == "Polish"')['subject'].unique().tolist()
subjects_polish[:5]
# Out:
# ['Operation of machines and equipment for earthworks and roadworks',
#  'Carrying out agricultural production',
#  'Installation and operation of computer systems, peripheral devices and networks',
#  'Providing help and organizing support for disabled people',
#  'Installation, commissioning and maintenance of ICT devices and networks']

# %%
subjects_to_combine = {
    'Agriculture': {},
    'Biology': {'Man and Nature'},
    'Business & Economics': {'Administration', 'Economics'},
    'Chemistry': {},
    'Citizenship': {}, # Specific for Vietnamese
    'Fine Arts': {},
    'Forestry': {}, # studies the craft of managing, using, conserving, and repairing forests, woodlands, and associated resources around them such as water sources and soil.
    'Geography': {},
    'Geology': {}, # Economical Geology, Marine Geology, Geomorphology, and Geophysics.
    'History': {},
    'Informatics': {},
    'Islamic Studies': {}, # refers to the academic studies of Islam, Quran excerpts, and Muslim morality. This a subject studied in the Qatari educational system during both middle and high school.
    'Landscaping': {'Gardening'},
    'Philosophy': {},
    'Physics': {},
    'Politics': {'Politics', 'Politics and Economics'},
    'Professional': set(subjects_polish),
    'Psychology': {'Psychology', 'Psycology'},
    'Religion': {'Religion', 'Religious Education', 'Religious Studies'},
    'Science': {'Math', 'Mathematics'},
    'Social': {}, # subject, similarly to Science, combines questions from political, cultural, historical and geographical studies.
    'Sociology': {'Man and Society'},
    'Ethics': {},
    'Tourism': {},
}

df_questions['subject_aggregated'] = df_questions['subject'].copy()
for aggregation, subjects in subjects_to_combine.items():
    df_questions.loc[df_questions['subject'].isin(subjects_to_combine[aggregation]), 'subject_aggregated'] = aggregation

pd.concat([
    df_questions['subject_aggregated'].value_counts(dropna=False).sort_index(),
    df_questions['subject_aggregated'].value_counts(dropna=False, normalize=True).sort_index().round(4) * 100,
], axis=1)
# Out:
#                       count  proportion
# subject_aggregated
# Agriculture             652        3.74
# Biology                1088        6.25
# Business & Economics   1149        6.60
# Chemistry              2437       13.99
# Ethics                  180        1.03
# Fine Arts                48        0.28
# Geography              1259        7.23
# History                 709        4.07
# Informatics             188        1.08
# Landscaping              27        0.15
# Philosophy              144        0.83
# Physics                4985       28.62
# Politics                270        1.55
# Professional           2511       14.41
# Psychology              154        0.88
# Religion                161        0.92
# Science                 823        4.72
# Sociology               559        3.21
# Tourism                  76        0.44

# %%
print(f'Aggregations for which there are no actual subjects: {set(subjects_to_combine.keys()) - set(df_questions["subject_aggregated"].unique())}')
print(f'Actual subjects for which there are no aggregations (should be empty): {set(df_questions["subject_aggregated"].unique()) - set(subjects_to_combine.keys())}')
# Out:
# Aggregations for which there are no actual subjects: {'Forestry', 'Islamic Studies', 'Geology', 'Social', 'Citizenship'}
# Actual subjects for which there are no aggregations (should be empty): set()

# %%
pd.concat([
    df_questions['subject_aggregated'].value_counts(dropna=False).sort_index(),
    df_questions['subject_aggregated'].value_counts(dropna=False, normalize=True).sort_index().round(4) * 100,
], axis=1)
# Out:
#                       count  proportion
# subject_aggregated
# Agriculture             652        3.74
# Biology                1088        6.25
# Business & Economics   1149        6.60
# Chemistry              2437       13.99
# Ethics                  180        1.03
# Fine Arts                48        0.28
# Geography              1259        7.23
# History                 709        4.07
# Informatics             188        1.08
# Landscaping              27        0.15
# Philosophy              144        0.83
# Physics                4985       28.62
# Politics                270        1.55
# Professional           2511       14.41
# Psychology              154        0.88
# Religion                161        0.92
# Science                 823        4.72
# Sociology               559        3.21
# Tourism                  76        0.44

# %%
# Number of subjects per language
df_questions.groupby(by=['language', 'grade'])['subject_aggregated'].nunique()
# Out:
# language   grade
# Bulgarian  4         2
#            12        2
# Chinese    4         6
# Croatian   12       13
# English    12        3
# French     12        3
# German     12        5
# Hungarian  12        7
# Italian    12        2
# Polish     12        1
# Romanian   12        1
# Russian    12        1
# Serbian    12        4
# Slovakian  12        1
# Spanish    12        2
# Name: subject_aggregated, dtype: int64

# %% [markdown]
# ## Group aggregated subjects

# %%
aggregations_to_combine = {
    'Natural Science': {'Biology', 'Geology', 'Chemistry', 'Physics', 'Science'}, # the study of natural phenomena
    'Social Sciences': {'Geography', 'History', 'Psychology', 'Politics', 'Social', 'Citizenship', 'Philosophy', 'Business & Economics', 'Sociology', 'Ethics'}, # the study of human behavior and societies
    'Other': {'Agriculture', 'Fine Arts', 'Forestry', 'Informatics', 'Islamic Studies', 'Landscaping', 'Professional', 'Religion', 'Tourism'}, # Applied Studies, Arts, Religion, etc.
}

df_questions['subject_aggregated_grouped'] = df_questions['subject_aggregated'].copy()
for superset, subjects in aggregations_to_combine.items():
    df_questions.loc[df_questions['subject_aggregated'].isin(aggregations_to_combine[superset]), 'subject_aggregated_grouped'] = superset

pd.concat([
    df_questions['subject_aggregated_grouped'].value_counts(dropna=False).sort_index(),
    df_questions['subject_aggregated_grouped'].value_counts(dropna=False, normalize=True).sort_index().round(4) * 100,
], axis=1)
# Out:
#                             count  proportion
# subject_aggregated_grouped
# Natural Science              9333       53.58
# Other                        3663       21.03
# Social Sciences              4424       25.40

# %% [markdown]
# # Create `test` sample

# %%
df_questions
# Out:
#                                          id answer_key  \
# 0      6d2efd56-6bed-43ec-af58-653d0dac578d          А
# 1      da5dd867-163c-4400-a316-57e32ba072e0          Г
# 2      10d911fb-fca1-4a16-aad2-87254b13d52b          А
# 3      58495517-d5fa-4391-aefa-77405e9586d1          А
# 4      559bcfe6-e72a-4fb5-b0c9-5c07fd91a507          В
# ...                                     ...        ...
# 17415  e88b9858-72e6-4733-9fbe-84a30e79cf0d          B
# 17416  a441aa2a-2cb8-4576-ab40-41ac48f33778          A
# 17417  a4be2ba5-9d50-42a2-8943-47eebe3a7a7d          B
# 17418  910bdfef-52e1-4f0e-bdf4-d6aa145974e3          D
# 17419  92187ce4-c0ec-4acb-87c1-8e2a5e13089d          C
#
#                                        question_snapshot  question_number  \
# 0      ../multiling-multichoice-rc-master/dataset/Bul...                1
# 1      ../multiling-multichoice-rc-master/dataset/Bul...                2
# 2      ../multiling-multichoice-rc-master/dataset/Bul...                3
# 3      ../multiling-multichoice-rc-master/dataset/Bul...                4
# 4      ../multiling-multichoice-rc-master/dataset/Bul...                5
# ...                                                  ...              ...
# 17415  ../multiling-multichoice-rc-master/dataset/Eng...               26
# 17416  ../multiling-multichoice-rc-master/dataset/Eng...               27
# 17417  ../multiling-multichoice-rc-master/dataset/Eng...               28
# 17418  ../multiling-multichoice-rc-master/dataset/Eng...               29
# 17419  ../multiling-multichoice-rc-master/dataset/Eng...               30
#
#        grade      subject   language        date        type  \
# 0         12      Physics  Bulgarian  2019-05-23        text
# 1         12      Physics  Bulgarian  2019-05-23  image_text
# 2         12      Physics  Bulgarian  2019-05-23  image_text
# 3         12      Physics  Bulgarian  2019-05-23  image_text
# 4         12      Physics  Bulgarian  2019-05-23  image_text
# ...      ...          ...        ...         ...         ...
# 17415     12  Mathematics    English        2013        text
# 17416     12  Mathematics    English        2013        text
# 17417     12  Mathematics    English        2013        text
# 17418     12  Mathematics    English        2013        text
# 17419     12  Mathematics    English        2013        text
#
#       subject_aggregated subject_aggregated_grouped
# 0                Physics            Natural Science
# 1                Physics            Natural Science
# 2                Physics            Natural Science
# 3                Physics            Natural Science
# 4                Physics            Natural Science
# ...                  ...                        ...
# 17415            Science            Natural Science
# 17416            Science            Natural Science
# 17417            Science            Natural Science
# 17418            Science            Natural Science
# 17419            Science            Natural Science
#
# [17420 rows x 11 columns]

# %% [markdown]
# ## Remove non-eligible triplets

# %%
num = 20
group = ['language', 'subject_aggregated', 'type']

df_num_per_group_check = df_questions.groupby(by=group).agg(number_questions=('id', 'count'))
df_num_per_group_check['has_at_least_num'] = df_num_per_group_check['number_questions'] >= num

df_num_per_group_check
# Out:
#                                          number_questions  has_at_least_num
# language  subject_aggregated type
# Bulgarian Biology            image_text                25              True
#                              text                     208              True
#           Chemistry          image_text               120              True
#                              text                     545              True
#           Physics            image_text               340              True
# ...                                                   ...               ...
# Slovakian Chemistry          image_text                 4             False
#                              text                      42              True
# Spanish   Geography          text                      19             False
#           Physics            image_text                89              True
#                              text                     191              True
#
# [81 rows x 2 columns]

# %%
df_num_per_group_check['has_at_least_num'].value_counts(dropna=False)
# Out:
# has_at_least_num
# True     65
# False    16
# Name: count, dtype: int64

# %%
# Eligible triplets
df_num_per_group_check.query('has_at_least_num').drop('has_at_least_num', axis=1).sort_values(by='number_questions', ascending=False).reset_index()
# Out:
#      language    subject_aggregated        type  number_questions
# 0      Polish          Professional        text              2090
# 1   Hungarian               Physics        text              1010
# 2   Hungarian  Business & Economics        text               727
# 3     Chinese             Geography          NA               678
# 4     Chinese               Science          NA               678
# ..        ...                   ...         ...               ...
# 60  Bulgarian               Biology  image_text                25
# 61    Italian             Geography        text                24
# 62     French             Geography        text                24
# 63    Serbian             Chemistry        text                23
# 64  Hungarian  Business & Economics  image_text                20
#
# [65 rows x 4 columns]

# %%
# Noneligible triplets
df_num_per_group_check.query('~has_at_least_num').drop('has_at_least_num', axis=1).sort_values(by='number_questions', ascending=False).reset_index()
# Out:
#      language    subject_aggregated        type  number_questions
# 0     Spanish             Geography        text                19
# 1   Bulgarian             Sociology  image_text                16
# 2     Italian               Physics        text                16
# 3      German             Chemistry        text                11
# 4     Russian             Geography        text                 9
# 5     Serbian             Chemistry  image_text                 7
# 6     Serbian  Business & Economics        text                 6
# 7     Serbian             Geography        text                 6
# 8      French  Business & Economics  image_text                 5
# 9    Romanian             Geography        text                 5
# 10    Italian               Physics  image_text                 4
# 11  Slovakian             Chemistry  image_text                 4
# 12     German  Business & Economics  image_text                 3
# 13     German             Chemistry  image_text                 3
# 14   Croatian             Fine Arts        text                 2
# 15  Hungarian           Agriculture  image_text                 1

# %%
df_eligible = df_num_per_group_check.query('has_at_least_num')
eligible = df_eligible.index.tolist()
print(f'{df_eligible.shape=}')
print(f'{eligible=}')
# Out:
# df_eligible.shape=(65, 2)
# eligible=[('Bulgarian', 'Biology', 'image_text'), ('Bulgarian', 'Biology', 'text'), ('Bulgarian', 'Chemistry', 'image_text'), ('Bulgarian', 'Chemistry', 'text'), ('Bulgarian', 'Physics', 'image_text'), ('Bulgarian', 'Physics', 'text'), ('Bulgarian', 'Sociology', 'text'), ('Chinese', 'Biology', 'NA'), ('Chinese', 'Chemistry', 'NA'), ('Chinese', 'Geography', 'NA'), ('Chinese', 'History', 'NA'), ('Chinese', 'Physics', 'NA'), ('Chinese', 'Science', 'NA'), ('Croatian', 'Biology', 'image_text'), ('Croatian', 'Biology', 'text'), ('Croatian', 'Chemistry', 'image_text'), ('Croatian', 'Chemistry', 'text'), ('Croatian', 'Ethics', 'text'), ('Croatian', 'Fine Arts', 'image_text'), ('Croatian', 'Geography', 'image_text'), ('Croatian', 'Geography', 'text'), ('Croatian', 'History', 'image_text'), ('Croatian', 'History', 'text'), ('Croatian', 'Informatics', 'image_text'), ('Croatian', 'Informatics', 'text'), ('Croatian', 'Philosophy', 'text'), ('Croatian', 'Physics', 'image_text'), ('Croatian', 'Physics', 'text'), ('Croatian', 'Politics', 'text'), ('Croatian', 'Psychology', 'text'), ('Croatian', 'Religion', 'text'), ('Croatian', 'Sociology', 'text'), ('English', 'Chemistry', 'image_text'), ('English', 'Chemistry', 'text'), ('English', 'Physics', 'image_text'), ('English', 'Physics', 'text'), ('English', 'Science', 'text'), ('French', 'Business & Economics', 'text'), ('French', 'Geography', 'text'), ('French', 'Physics', 'image_text'), ('French', 'Physics', 'text'), ('German', 'Business & Economics', 'text'), ('German', 'Geography', 'text'), ('German', 'Physics', 'image_text'), ('German', 'Physics', 'text'), ('German', 'Tourism', 'text'), ('Hungarian', 'Agriculture', 'text'), ('Hungarian', 'Business & Economics', 'image_text'), ('Hungarian', 'Business & Economics', 'text'), ('Hungarian', 'Chemistry', 'image_text'), ('Hungarian', 'Chemistry', 'text'), ('Hungarian', 'Geography', 'text'), ('Hungarian', 'Landscaping', 'text'), ('Hungarian', 'Physics', 'image_text'), ('Hungarian', 'Physics', 'text'), ('Hungarian', 'Tourism', 'text'), ('Italian', 'Geography', 'text'), ('Polish', 'Professional', 'image_text'), ('Polish', 'Professional', 'text'), ('Serbian', 'Chemistry', 'text'), ('Serbian', 'Physics', 'image_text'), ('Serbian', 'Physics', 'text'), ('Slovakian', 'Chemistry', 'text'), ('Spanish', 'Physics', 'image_text'), ('Spanish', 'Physics', 'text')]

# %% [markdown]
# ## Full test sample

# %%
df_questions_test_sample_full = df_questions.set_index(group)
df_questions_test_sample_full = df_questions_test_sample_full.iloc[df_questions_test_sample_full.index.isin(eligible)]
df_questions_test_sample_full = df_questions_test_sample_full.reset_index(drop=False)
df_questions_test_sample_full
# Out:
#         language subject_aggregated        type  \
# 0      Bulgarian            Physics        text
# 1      Bulgarian            Physics  image_text
# 2      Bulgarian            Physics  image_text
# 3      Bulgarian            Physics  image_text
# 4      Bulgarian            Physics  image_text
# ...          ...                ...         ...
# 17298    English            Science        text
# 17299    English            Science        text
# 17300    English            Science        text
# 17301    English            Science        text
# 17302    English            Science        text
#
#                                          id answer_key  \
# 0      6d2efd56-6bed-43ec-af58-653d0dac578d          А
# 1      da5dd867-163c-4400-a316-57e32ba072e0          Г
# 2      10d911fb-fca1-4a16-aad2-87254b13d52b          А
# 3      58495517-d5fa-4391-aefa-77405e9586d1          А
# 4      559bcfe6-e72a-4fb5-b0c9-5c07fd91a507          В
# ...                                     ...        ...
# 17298  e88b9858-72e6-4733-9fbe-84a30e79cf0d          B
# 17299  a441aa2a-2cb8-4576-ab40-41ac48f33778          A
# 17300  a4be2ba5-9d50-42a2-8943-47eebe3a7a7d          B
# 17301  910bdfef-52e1-4f0e-bdf4-d6aa145974e3          D
# 17302  92187ce4-c0ec-4acb-87c1-8e2a5e13089d          C
#
#                                        question_snapshot  question_number  \
# 0      ../multiling-multichoice-rc-master/dataset/Bul...                1
# 1      ../multiling-multichoice-rc-master/dataset/Bul...                2
# 2      ../multiling-multichoice-rc-master/dataset/Bul...                3
# 3      ../multiling-multichoice-rc-master/dataset/Bul...                4
# 4      ../multiling-multichoice-rc-master/dataset/Bul...                5
# ...                                                  ...              ...
# 17298  ../multiling-multichoice-rc-master/dataset/Eng...               26
# 17299  ../multiling-multichoice-rc-master/dataset/Eng...               27
# 17300  ../multiling-multichoice-rc-master/dataset/Eng...               28
# 17301  ../multiling-multichoice-rc-master/dataset/Eng...               29
# 17302  ../multiling-multichoice-rc-master/dataset/Eng...               30
#
#        grade      subject        date subject_aggregated_grouped
# 0         12      Physics  2019-05-23            Natural Science
# 1         12      Physics  2019-05-23            Natural Science
# 2         12      Physics  2019-05-23            Natural Science
# 3         12      Physics  2019-05-23            Natural Science
# 4         12      Physics  2019-05-23            Natural Science
# ...      ...          ...         ...                        ...
# 17298     12  Mathematics        2013            Natural Science
# 17299     12  Mathematics        2013            Natural Science
# 17300     12  Mathematics        2013            Natural Science
# 17301     12  Mathematics        2013            Natural Science
# 17302     12  Mathematics        2013            Natural Science
#
# [17303 rows x 11 columns]

# %% [markdown]
# ## Split for sampling (remove Chinese)

# %%
df_to_sample = df_eligible.query('number_questions > 50')
triplets_sample = df_to_sample.index.tolist()

df_ready = df_eligible.query('number_questions <= 50')
triplets_ready = df_ready.index.tolist()

## Remove Chinese
# triplets_sample = [el for el in triplets_sample if el[0] != 'Chinese']
# triplets_ready = [el for el in triplets_ready if el[0] != 'Chinese']

print('Triplets that are ready:')
print(f'{df_ready.shape=}')
print(f'{triplets_ready=}')

print('\nTriplets that need sampling:')
print(f'{df_to_sample.shape=}')
print(f'{triplets_sample=}')
# Out:
# Triplets that are ready:
# df_ready.shape=(12, 2)
# triplets_ready=[('Bulgarian', 'Biology', 'image_text'), ('Croatian', 'Fine Arts', 'image_text'), ('Croatian', 'Informatics', 'image_text'), ('French', 'Geography', 'text'), ('German', 'Geography', 'text'), ('German', 'Tourism', 'text'), ('Hungarian', 'Business & Economics', 'image_text'), ('Hungarian', 'Landscaping', 'text'), ('Hungarian', 'Tourism', 'text'), ('Italian', 'Geography', 'text'), ('Serbian', 'Chemistry', 'text'), ('Slovakian', 'Chemistry', 'text')]
#
# Triplets that need sampling:
# df_to_sample.shape=(53, 2)
# triplets_sample=[('Bulgarian', 'Biology', 'text'), ('Bulgarian', 'Chemistry', 'image_text'), ('Bulgarian', 'Chemistry', 'text'), ('Bulgarian', 'Physics', 'image_text'), ('Bulgarian', 'Physics', 'text'), ('Bulgarian', 'Sociology', 'text'), ('Chinese', 'Biology', 'NA'), ('Chinese', 'Chemistry', 'NA'), ('Chinese', 'Geography', 'NA'), ('Chinese', 'History', 'NA'), ('Chinese', 'Physics', 'NA'), ('Chinese', 'Science', 'NA'), ('Croatian', 'Biology', 'image_text'), ('Croatian', 'Biology', 'text'), ('Croatian', 'Chemistry', 'image_text'), ('Croatian', 'Chemistry', 'text'), ('Croatian', 'Ethics', 'text'), ('Croatian', 'Geography', 'image_text'), ('Croatian', 'Geography', 'text'), ('Croatian', 'History', 'image_text'), ('Croatian', 'History', 'text'), ('Croatian', 'Informatics', 'text'), ('Croatian', 'Philosophy', 'text'), ('Croatian', 'Physics', 'image_text'), ('Croatian', 'Physics', 'text'), ('Croatian', 'Politics', 'text'), ('Croatian', 'Psychology', 'text'), ('Croatian', 'Religion', 'text'), ('Croatian', 'Sociology', 'text'), ('English', 'Chemistry', 'image_text'), ('English', 'Chemistry', 'text'), ('English', 'Physics', 'image_text'), ('English', 'Physics', 'text'), ('English', 'Science', 'text'), ('French', 'Business & Economics', 'text'), ('French', 'Physics', 'image_text'), ('French', 'Physics', 'text'), ('German', 'Business & Economics', 'text'), ('German', 'Physics', 'image_text'), ('German', 'Physics', 'text'), ('Hungarian', 'Agriculture', 'text'), ('Hungarian', 'Business & Economics', 'text'), ('Hungarian', 'Chemistry', 'image_text'), ('Hungarian', 'Chemistry', 'text'), ('Hungarian', 'Geography', 'text'), ('Hungarian', 'Physics', 'image_text'), ('Hungarian', 'Physics', 'text'), ('Polish', 'Professional', 'image_text'), ('Polish', 'Professional', 'text'), ('Serbian', 'Physics', 'image_text'), ('Serbian', 'Physics', 'text'), ('Spanish', 'Physics', 'image_text'), ('Spanish', 'Physics', 'text')]

# %% [markdown]
# ## Sample

# %%
df_questions_test_sample_more_than_50 = df_questions.set_index(group)
df_questions_test_sample_more_than_50 = df_questions_test_sample_more_than_50.iloc[df_questions_test_sample_more_than_50.index.isin(triplets_sample)]
df_questions_test_sample_more_than_50 = df_questions_test_sample_more_than_50.reset_index(drop=False)
df_questions_test_sample_more_than_50
# Out:
#         language subject_aggregated        type  \
# 0      Bulgarian            Physics        text
# 1      Bulgarian            Physics  image_text
# 2      Bulgarian            Physics  image_text
# 3      Bulgarian            Physics  image_text
# 4      Bulgarian            Physics  image_text
# ...          ...                ...         ...
# 16912    English            Science        text
# 16913    English            Science        text
# 16914    English            Science        text
# 16915    English            Science        text
# 16916    English            Science        text
#
#                                          id answer_key  \
# 0      6d2efd56-6bed-43ec-af58-653d0dac578d          А
# 1      da5dd867-163c-4400-a316-57e32ba072e0          Г
# 2      10d911fb-fca1-4a16-aad2-87254b13d52b          А
# 3      58495517-d5fa-4391-aefa-77405e9586d1          А
# 4      559bcfe6-e72a-4fb5-b0c9-5c07fd91a507          В
# ...                                     ...        ...
# 16912  e88b9858-72e6-4733-9fbe-84a30e79cf0d          B
# 16913  a441aa2a-2cb8-4576-ab40-41ac48f33778          A
# 16914  a4be2ba5-9d50-42a2-8943-47eebe3a7a7d          B
# 16915  910bdfef-52e1-4f0e-bdf4-d6aa145974e3          D
# 16916  92187ce4-c0ec-4acb-87c1-8e2a5e13089d          C
#
#                                        question_snapshot  question_number  \
# 0      ../multiling-multichoice-rc-master/dataset/Bul...                1
# 1      ../multiling-multichoice-rc-master/dataset/Bul...                2
# 2      ../multiling-multichoice-rc-master/dataset/Bul...                3
# 3      ../multiling-multichoice-rc-master/dataset/Bul...                4
# 4      ../multiling-multichoice-rc-master/dataset/Bul...                5
# ...                                                  ...              ...
# 16912  ../multiling-multichoice-rc-master/dataset/Eng...               26
# 16913  ../multiling-multichoice-rc-master/dataset/Eng...               27
# 16914  ../multiling-multichoice-rc-master/dataset/Eng...               28
# 16915  ../multiling-multichoice-rc-master/dataset/Eng...               29
# 16916  ../multiling-multichoice-rc-master/dataset/Eng...               30
#
#        grade      subject        date subject_aggregated_grouped
# 0         12      Physics  2019-05-23            Natural Science
# 1         12      Physics  2019-05-23            Natural Science
# 2         12      Physics  2019-05-23            Natural Science
# 3         12      Physics  2019-05-23            Natural Science
# 4         12      Physics  2019-05-23            Natural Science
# ...      ...          ...         ...                        ...
# 16912     12  Mathematics        2013            Natural Science
# 16913     12  Mathematics        2013            Natural Science
# 16914     12  Mathematics        2013            Natural Science
# 16915     12  Mathematics        2013            Natural Science
# 16916     12  Mathematics        2013            Natural Science
#
# [16917 rows x 11 columns]

# %%
df_questions_test_sample_part2 = df_questions_test_sample_more_than_50.groupby(by=group).sample(n=50, random_state=42).reset_index(drop=True)
df_questions_test_sample_part2
# Out:
#        language subject_aggregated  type  \
# 0     Bulgarian            Biology  text
# 1     Bulgarian            Biology  text
# 2     Bulgarian            Biology  text
# 3     Bulgarian            Biology  text
# 4     Bulgarian            Biology  text
# ...         ...                ...   ...
# 2645    Spanish            Physics  text
# 2646    Spanish            Physics  text
# 2647    Spanish            Physics  text
# 2648    Spanish            Physics  text
# 2649    Spanish            Physics  text
#
#                                         id answer_key  \
# 0     fa8b2d6f-5ffe-4fcd-8e6e-3c6f10e16246          б
# 1     20c70435-a53e-4aeb-b997-d508a7b15d8f          В
# 2     378b4e57-5e9d-49bd-9c17-4bc07dc5be70          в
# 3     e40a7130-8a93-4f7f-92e4-1bca8c180f71          В
# 4     54b8b2e4-5918-4375-b17b-5fe29b3d01b3          а
# ...                                    ...        ...
# 2645  7e4ff589-7699-4d51-b93b-57c3624eb922          B
# 2646  29dc1421-7acf-4751-bb4d-088e1908f92f          C
# 2647  2624af36-12e1-4b1b-bf23-8442f91bdd64          C
# 2648  f9203c52-3f86-4027-914d-1cf383505c3f          A
# 2649  30423cd1-f1c9-4609-9de2-772873922659          B
#
#                                       question_snapshot  question_number  \
# 0     ../multiling-multichoice-rc-master/dataset/Bul...                4
# 1     ../multiling-multichoice-rc-master/dataset/Bul...                4
# 2     ../multiling-multichoice-rc-master/dataset/Bul...                6
# 3     ../multiling-multichoice-rc-master/dataset/Bul...               11
# 4     ../multiling-multichoice-rc-master/dataset/Bul...               12
# ...                                                 ...              ...
# 2645  ../multiling-multichoice-rc-master/dataset/Hun...               13
# 2646  ../multiling-multichoice-rc-master/dataset/Hun...               11
# 2647  ../multiling-multichoice-rc-master/dataset/Hun...               13
# 2648  ../multiling-multichoice-rc-master/dataset/Hun...               20
# 2649  ../multiling-multichoice-rc-master/dataset/Hun...                4
#
#       grade         subject        date subject_aggregated_grouped
# 0         4  Man and Nature  2011-05-10            Natural Science
# 1         4  Man and Nature  2012-10-03            Natural Science
# 2         4  Man and Nature  2010-05-12            Natural Science
# 3         4  Man and Nature  2012-05-14            Natural Science
# 4         4  Man and Nature  2011-05-10            Natural Science
# ...     ...             ...         ...                        ...
# 2645     12         Physics  2008-11-03            Natural Science
# 2646     12         Physics  2012-05-17            Natural Science
# 2647     12         Physics  2017-05-22            Natural Science
# 2648     12         Physics  2006-05-15            Natural Science
# 2649     12         Physics  2007-05-14            Natural Science
#
# [2650 rows x 11 columns]

# %%
df_questions_test_sample_ready = df_questions.set_index(group)
df_questions_test_sample_ready = df_questions_test_sample_ready.iloc[df_questions_test_sample_ready.index.isin(triplets_ready)]
df_questions_test_sample_ready = df_questions_test_sample_ready.reset_index(drop=False)
df_questions_test_sample_ready
# Out:
#       language subject_aggregated        type  \
# 0    Bulgarian            Biology  image_text
# 1    Bulgarian            Biology  image_text
# 2    Bulgarian            Biology  image_text
# 3    Bulgarian            Biology  image_text
# 4    Bulgarian            Biology  image_text
# ..         ...                ...         ...
# 381  Hungarian            Tourism        text
# 382  Hungarian            Tourism        text
# 383  Hungarian            Tourism        text
# 384  Hungarian            Tourism        text
# 385  Hungarian            Tourism        text
#
#                                        id answer_key  \
# 0    7028d47d-c221-4021-b3d2-969eb4eea85b          В
# 1    138519c5-1952-4286-81ba-329e5dfb8cea          Б
# 2    f0d208e5-9a6d-4b26-9bdc-29f309040fed          А
# 3    46ec0375-f51e-4d8d-bfc2-8255c85f4a4e          А
# 4    44cfa1bc-2536-4def-823a-dff1682118a0          В
# ..                                    ...        ...
# 381  0dd9a8ed-94f8-49ac-9ccb-9edc65ced1b3          D
# 382  9bf58153-883c-4130-a439-15b8fe994941          C
# 383  680dd8f2-c67b-45b4-b22c-58b9463c9d56          B
# 384  06ab008d-2f33-4ba7-b857-572cdaf38771          C
# 385  1ca3f117-a57a-40a4-95b2-082c9196f027          A
#
#                                      question_snapshot  question_number  \
# 0    ../multiling-multichoice-rc-master/dataset/Bul...                9
# 1    ../multiling-multichoice-rc-master/dataset/Bul...               10
# 2    ../multiling-multichoice-rc-master/dataset/Bul...               15
# 3    ../multiling-multichoice-rc-master/dataset/Bul...               16
# 4    ../multiling-multichoice-rc-master/dataset/Bul...                6
# ..                                                 ...              ...
# 381  ../multiling-multichoice-rc-master/dataset/Hun...                4
# 382  ../multiling-multichoice-rc-master/dataset/Hun...                5
# 383  ../multiling-multichoice-rc-master/dataset/Hun...                6
# 384  ../multiling-multichoice-rc-master/dataset/Hun...                7
# 385  ../multiling-multichoice-rc-master/dataset/Hun...                8
#
#      grade         subject        date subject_aggregated_grouped
# 0        4  Man and Nature  2014-05-12            Natural Science
# 1        4  Man and Nature  2014-05-12            Natural Science
# 2        4  Man and Nature  2014-05-12            Natural Science
# 3        4  Man and Nature  2014-05-12            Natural Science
# 4        4  Man and Nature  2012-10-03            Natural Science
# ..     ...             ...         ...                        ...
# 381     12         Tourism  2018-10-19                      Other
# 382     12         Tourism  2018-10-19                      Other
# 383     12         Tourism  2018-10-19                      Other
# 384     12         Tourism  2018-10-19                      Other
# 385     12         Tourism  2018-10-19                      Other
#
# [386 rows x 11 columns]

# %% [markdown]
# ## Merge to obtain final test sample

# %%
df_test = pd.concat([
    df_questions_test_sample_ready,
    df_questions_test_sample_part2
], ignore_index=True)
df_test
# Out:
#        language subject_aggregated        type  \
# 0     Bulgarian            Biology  image_text
# 1     Bulgarian            Biology  image_text
# 2     Bulgarian            Biology  image_text
# 3     Bulgarian            Biology  image_text
# 4     Bulgarian            Biology  image_text
# ...         ...                ...         ...
# 3031    Spanish            Physics        text
# 3032    Spanish            Physics        text
# 3033    Spanish            Physics        text
# 3034    Spanish            Physics        text
# 3035    Spanish            Physics        text
#
#                                         id answer_key  \
# 0     7028d47d-c221-4021-b3d2-969eb4eea85b          В
# 1     138519c5-1952-4286-81ba-329e5dfb8cea          Б
# 2     f0d208e5-9a6d-4b26-9bdc-29f309040fed          А
# 3     46ec0375-f51e-4d8d-bfc2-8255c85f4a4e          А
# 4     44cfa1bc-2536-4def-823a-dff1682118a0          В
# ...                                    ...        ...
# 3031  7e4ff589-7699-4d51-b93b-57c3624eb922          B
# 3032  29dc1421-7acf-4751-bb4d-088e1908f92f          C
# 3033  2624af36-12e1-4b1b-bf23-8442f91bdd64          C
# 3034  f9203c52-3f86-4027-914d-1cf383505c3f          A
# 3035  30423cd1-f1c9-4609-9de2-772873922659          B
#
#                                       question_snapshot  question_number  \
# 0     ../multiling-multichoice-rc-master/dataset/Bul...                9
# 1     ../multiling-multichoice-rc-master/dataset/Bul...               10
# 2     ../multiling-multichoice-rc-master/dataset/Bul...               15
# 3     ../multiling-multichoice-rc-master/dataset/Bul...               16
# 4     ../multiling-multichoice-rc-master/dataset/Bul...                6
# ...                                                 ...              ...
# 3031  ../multiling-multichoice-rc-master/dataset/Hun...               13
# 3032  ../multiling-multichoice-rc-master/dataset/Hun...               11
# 3033  ../multiling-multichoice-rc-master/dataset/Hun...               13
# 3034  ../multiling-multichoice-rc-master/dataset/Hun...               20
# 3035  ../multiling-multichoice-rc-master/dataset/Hun...                4
#
#       grade         subject        date subject_aggregated_grouped
# 0         4  Man and Nature  2014-05-12            Natural Science
# 1         4  Man and Nature  2014-05-12            Natural Science
# 2         4  Man and Nature  2014-05-12            Natural Science
# 3         4  Man and Nature  2014-05-12            Natural Science
# 4         4  Man and Nature  2012-10-03            Natural Science
# ...     ...             ...         ...                        ...
# 3031     12         Physics  2008-11-03            Natural Science
# 3032     12         Physics  2012-05-17            Natural Science
# 3033     12         Physics  2017-05-22            Natural Science
# 3034     12         Physics  2006-05-15            Natural Science
# 3035     12         Physics  2007-05-14            Natural Science
#
# [3036 rows x 11 columns]

# %% [markdown]
# ## Subsample 10 from group

# %%
df_test_mini = df_test.groupby(by=group).sample(n=10, random_state=42).reset_index(drop=True)
df_test_mini
# Out:
#       language subject_aggregated        type  \
# 0    Bulgarian            Biology  image_text
# 1    Bulgarian            Biology  image_text
# 2    Bulgarian            Biology  image_text
# 3    Bulgarian            Biology  image_text
# 4    Bulgarian            Biology  image_text
# ..         ...                ...         ...
# 645    Spanish            Physics        text
# 646    Spanish            Physics        text
# 647    Spanish            Physics        text
# 648    Spanish            Physics        text
# 649    Spanish            Physics        text
#
#                                        id answer_key  \
# 0    223f1e74-14b0-4d8a-bc0b-f2240aa1c027          Б
# 1    558bcd64-8770-47d8-9bb0-ecbd084ba07c          В
# 2    7028d47d-c221-4021-b3d2-969eb4eea85b          В
# 3    da86ffde-ecb3-4f61-a02c-d1155023ce32          Б
# 4    a4e787d6-2a25-4c1b-aa12-adc704c683f8          А
# ..                                    ...        ...
# 645  27f90aa7-297a-4763-b4e7-5eccbd4f2448          A
# 646  733583aa-74de-451a-84fc-443a2144b9ac          B
# 647  d41cd2d5-5767-4d99-a905-758b3033342d          C
# 648  6591ed40-2b27-4c4d-b7bc-faed1ce34a43          A
# 649  83b97ad4-b3b6-4fbe-81f4-02143369cce1          C
#
#                                      question_snapshot  question_number  \
# 0    ../multiling-multichoice-rc-master/dataset/Bul...                1
# 1    ../multiling-multichoice-rc-master/dataset/Bul...               20
# 2    ../multiling-multichoice-rc-master/dataset/Bul...                9
# 3    ../multiling-multichoice-rc-master/dataset/Bul...                8
# 4    ../multiling-multichoice-rc-master/dataset/Bul...               12
# ..                                                 ...              ...
# 645  ../multiling-multichoice-rc-master/dataset/Hun...                5
# 646  ../multiling-multichoice-rc-master/dataset/Hun...                3
# 647  ../multiling-multichoice-rc-master/dataset/Hun...                9
# 648  ../multiling-multichoice-rc-master/dataset/Hun...                9
# 649  ../multiling-multichoice-rc-master/dataset/Hun...               20
#
#      grade         subject        date subject_aggregated_grouped
# 0        4  Man and Nature  2013-05-15            Natural Science
# 1        4  Man and Nature  2012-05-14            Natural Science
# 2        4  Man and Nature  2014-05-12            Natural Science
# 3        4  Man and Nature  2017-05-15            Natural Science
# 4        4  Man and Nature  2018-05-17            Natural Science
# ..     ...             ...         ...                        ...
# 645     12         Physics  2018-05-22            Natural Science
# 646     12         Physics  2006-05-15            Natural Science
# 647     12         Physics  2013-05-16            Natural Science
# 648     12         Physics  2007-05-14            Natural Science
# 649     12         Physics  2014-05-19            Natural Science
#
# [650 rows x 11 columns]

# %% [markdown]
# ## Checks

# %%
df_test.groupby(by=group).agg(number_questions=('id', 'count'))
# Out:
#                                          number_questions
# language  subject_aggregated type
# Bulgarian Biology            image_text                25
#                              text                      50
#           Chemistry          image_text                50
#                              text                      50
#           Physics            image_text                50
# ...                                                   ...
# Serbian   Physics            image_text                50
#                              text                      50
# Slovakian Chemistry          text                      42
# Spanish   Physics            image_text                50
#                              text                      50
#
# [65 rows x 1 columns]

# %%
df_test_mini.groupby(by=group).agg(number_questions=('id', 'count'))

# %% [markdown]
# # Create folder structure

# %% [markdown]
# ## Test sample

# %%
path_test_dataset = Path('./test_dataset')
path_test_dataset

# %%
if path_test_dataset.exists():
    shutil.rmtree(path_test_dataset)
path_test_dataset.mkdir()


def get_annotation_file(cropped_image: Path, language: str, subject: str) -> dict | None:
    for annotation_file in annotations:
        current_annotations = json.loads(annotation_file.read_bytes())
        for idx, current_annotation in enumerate(current_annotations):
            if current_annotation['info']['language'] == language \
                and current_annotation['info']['subject'] == subject:
                if str(cropped_image) == preprocess(current_annotation['question']['question_snapshot']):
                    return current_annotations[idx]
    return None


types = ['image_text', 'text']
languages = df_test['language'].unique()

for language in tqdm(languages):
    path_lang_folder = path_test_dataset / language
    path_lang_folder.mkdir()
    
    subjects_agg = df_test.query(f'language == "{language}"')['subject_aggregated'].unique()

    for subject_agg in subjects_agg:
        path_subj_folder = path_lang_folder / subject_agg
        path_subj_folder.mkdir()

        for q_type in types:
            annotations_q_type = []
            path_type_folder = path_subj_folder / q_type
            path_type_folder_ims = path_subj_folder / q_type / 'images'
            path_type_folder_ims_annotations = path_subj_folder / q_type / 'annotations.json'
            path_type_folder.mkdir()
            path_type_folder_ims.mkdir()

            query = f'language == "{language}" and subject_aggregated == "{subject_agg}" and type == "{q_type}"'
            df_subset = df_test.query(query)

            for idx, row in df_subset.iterrows():
                src = Path(row['question_snapshot'])
                subject = row['subject']
                dst = path_type_folder_ims / f'{idx:02}_{src.name}'

                assert src.exists(), f'ERROR: File {src} not found!'

                if '541_page_02_cropped_05' in str(dst):
                    print(src)

                shutil.copyfile(src, dst)

                annotation = get_annotation_file(src, language, subject)
                assert annotation is not None, f'ERROR: No annotation file for {src}!'
                annotations_q_type.append(annotation)

            with open(path_type_folder_ims_annotations, 'w') as f:
                json.dump(annotations_q_type, f, ensure_ascii=False)

# %% [markdown]
# ## Test sample mini

# %%
path_test_dataset_mini = Path('./test_dataset_mini')
path_test_dataset_mini

# %%
if path_test_dataset_mini.exists():
    shutil.rmtree(path_test_dataset_mini)
path_test_dataset_mini.mkdir()


def get_annotation_file(cropped_image: Path, language: str, subject: str) -> dict | None:
    for annotation_file in annotations:
        current_annotations = json.loads(annotation_file.read_bytes())
        for idx, current_annotation in enumerate(current_annotations):
            if current_annotation['info']['language'] == language \
                and current_annotation['info']['subject'] == subject:
                if str(cropped_image) == preprocess(current_annotation['question']['question_snapshot']):
                    return current_annotations[idx]
    return None


types = ['image_text', 'text']
languages = df_test_mini['language'].unique()

for language in tqdm(languages):
    path_lang_folder = path_test_dataset_mini / language
    path_lang_folder.mkdir()
    
    subjects_agg = df_test_mini.query(f'language == "{language}"')['subject_aggregated'].unique()

    for subject_agg in subjects_agg:
        path_subj_folder = path_lang_folder / subject_agg
        path_subj_folder.mkdir()

        for q_type in types:
            annotations_q_type = []
            path_type_folder = path_subj_folder / q_type
            path_type_folder_ims = path_subj_folder / q_type / 'images'
            path_type_folder_ims_annotations = path_subj_folder / q_type / 'annotations.json'
            path_type_folder.mkdir()
            path_type_folder_ims.mkdir()

            query = f'language == "{language}" and subject_aggregated == "{subject_agg}" and type == "{q_type}"'
            df_subset = df_test_mini.query(query)

            for idx, row in df_subset.iterrows():
                src = Path(row['question_snapshot'])
                subject = row['subject']
                dst = path_type_folder_ims / f'{idx:02}_{src.name}'

                assert src.exists(), f'ERROR: File {src} not found!'

                shutil.copyfile(src, dst)

                annotation = get_annotation_file(src, language, subject)
                assert annotation is not None, f'ERROR: No annotation file for {src}!'
                annotations_q_type.append(annotation)

            with open(path_type_folder_ims_annotations, 'w') as f:
                json.dump(annotations_q_type, f, ensure_ascii=False)

# %% [markdown]
# # Send to BARD

# %%
session = requests.Session()

# __Secure-1PSID token
token1 = "dQhzAC701XnEp4srLnf3Pk0EHjl8tq-Og4JKQ14EvYSZ0RomEP-Ggsq4F1IH8goNIhPqBw."

# __Secure-1PSIDCC token
token2 = "ABTWhQHXt63d4S9fxRW9IxNP3seeLhhVjiLxILYATtkbO8j_htbF_5Vp6uq7gRFkppbUwziAgrja"

# __Secure-1PSIDTS token
token3 = "sidts-CjEBPVxjSmQx_3nNH7vfRtjJzWlIq0NOMzGlzv801vGdL52Evqrzj0IV_3EZ59-r-56YEAA"

session.cookies.set("__Secure-1PSID", token1)
session.cookies.set("__Secure-1PSIDCC", token2)
session.cookies.set("__Secure-1PSIDTS", token3)

session.headers = SESSION_HEADERS

bard = Bard(token=token1, session=session, timeout=300)
# result = bard.get_answer("How is the weather today in Seoul?")
# print(result) 

START_INDEX = 1803
NUM_TO_PASS_TO_BARD = 89
PROMPT = "The image has an multiple choice question with 3 to 5 choices. Provide the correct answer precisely in JSON format as follows: {'answer': 'xxx'}. Replace 'xxx' with the appropriate letter: 'A' if the first choice is correct, 'B' if the second choice is correct, 'C' if the third choice is correct, 'D' if the fourth choice is correct, or 'E' if the fifth choice is correct."

df_bard = df_test.iloc[range(START_INDEX, START_INDEX + NUM_TO_PASS_TO_BARD)]
df_bard['content'] = 'NA'

bard_answers = []
for idx, row in tqdm(df_bard.iterrows()):
    with open(row['question_snapshot'], 'rb') as image:
        bard_answer = bard.ask_about_image(PROMPT, image.read())
        # print(bard_answer['content'][:10])
        bard_answers.append(bard_answer)
        df_bard.at[idx, 'content'] = bard_answer['content']
df_bard
# Out:
# /tmp/ipykernel_113573/1410821524.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bard['content'] = 'NA'
# 89it [17:11, 11.60s/it]
#       language subject_aggregated  type                                    id  \
# 1714  Croatian         Psychology  text  26dbf0c3-fb58-4fda-aff6-8c9afde2dfb1
# 1715  Croatian         Psychology  text  dec74646-4d00-4bb7-ad6f-28115b26f011
# 1716  Croatian         Psychology  text  ce63a9c1-e210-47f4-b887-98c8719f695c
# 1717  Croatian         Psychology  text  e8f8e669-2d31-4b12-b9d8-3fe99335d26a
# 1718  Croatian         Psychology  text  5b0c4ec7-5c4b-4b9c-ad34-91fa67807e66
# ...        ...                ...   ...                                   ...
# 1798  Croatian          Sociology  text  70fe836f-2dba-467f-bebc-1dcbcf6c3b60
# 1799  Croatian          Sociology  text  a4da5c61-c462-4065-ace7-670e49cc3e27
# 1800  Croatian          Sociology  text  d0a44e6e-ce7a-4afd-9926-e44d23e52397
# 1801  Croatian          Sociology  text  b75447be-6c92-4d46-b87c-e67ad80ee93c
# 1802  Croatian          Sociology  text  ed024280-20e4-4d96-a087-ef06256fde9c
#
#      answer_key                                  question_snapshot  \
# 1714          C  ../multiling-multichoice-rc-master/dataset/Cro...
# 1715          B  ../multiling-multichoice-rc-master/dataset/Cro...
# 1716          C  ../multiling-multichoice-rc-master/dataset/Cro...
# 1717          A  ../multiling-multichoice-rc-master/dataset/Cro...
# 1718          C  ../multiling-multichoice-rc-master/dataset/Cro...
# ...         ...                                                ...
# 1798          D  ../multiling-multichoice-rc-master/dataset/Cro...
# 1799          B  ../multiling-multichoice-rc-master/dataset/Cro...
# 1800          C  ../multiling-multichoice-rc-master/dataset/Cro...
# 1801          D  ../multiling-multichoice-rc-master/dataset/Cro...
# 1802          C  ../multiling-multichoice-rc-master/dataset/Cro...
#
#       question_number  grade     subject        date  \
# 1714                5     12  Psychology  2014-06-10
# 1715                3     12  Psychology     2019-06
# 1716               18     12  Psychology     2017-06
# 1717               10     12  Psychology  2016-04-06
# 1718               13     12  Psychology     2017-06
# ...               ...    ...         ...         ...
# 1798               23     12   Sociology  2015-07-01
# 1799               20     12   Sociology  2016-06-30
# 1800               27     12   Sociology  2015-07-01
# 1801               10     12   Sociology     2018-09
# 1802                9     12   Sociology  2015-04-13
#
#      subject_aggregated_grouped  \
# 1714            Social Sciences
# 1715            Social Sciences
# 1716            Social Sciences
# 1717            Social Sciences
# 1718            Social Sciences
# ...                         ...
# 1798            Social Sciences
# 1799            Social Sciences
# 1800            Social Sciences
# 1801            Social Sciences
# 1802            Social Sciences
#
#                                                 content
# 1714  The correct answer to the multiple choice ques...
# 1715                                    {'answer': 'B'}
# 1716  The correct answer is A, visoka toplina i viso...
# 1717                                    {'answer': 'A'}
# 1718                                    {'answer': 'D'}
# ...                                                 ...
# 1798  The correct answer is **A**.\n\n**JSON format:...
# 1799  The correct answer to the multiple choice ques...
# 1800  The correct answer to the multiple choice ques...
# 1801  The answer to the multiple choice question in ...
# 1802  The correct answer to the multiple choice ques...
#
# [89 rows x 12 columns]

# %%
df_bard.to_csv('BARD_035_gemini.csv', index=False)
